# %%
import pandas as pd

# %%
df=pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  DiabetesPedigreeFunction  Age  Outcome
# 0              6      148             72             35        0  33.6                     0.627   50        1
# 1              1       85             66             29        0  26.6                     0.351   31        0
# 2              8      183             64              0        0  23.3                     0.672   32        1
# 3              1       89             66             23       94  28.1                     0.167   21        0
# 4              0      137             40             35      168  43.1                     2.288   33        1
# ..           ...      ...            ...            ...      ...   ...                       ...  ...      ...
# 763           10      101             76             48      180  32.9                     0.171   63        0
# ...

# %%
x_change=df[['Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']]
x_change
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  DiabetesPedigreeFunction  Age
# 0        148             72             35        0  33.6                     0.627   50
# 1         85             66             29        0  26.6                     0.351   31
# 2        183             64              0        0  23.3                     0.672   32
# 3         89             66             23       94  28.1                     0.167   21
# 4        137             40             35      168  43.1                     2.288   33
# ..       ...            ...            ...      ...   ...                       ...  ...
# 763      101             76             48      180  32.9                     0.171   63
# 764      122             70             27        0  36.8                     0.340   27
# 765      121             72             23      112  26.2                     0.245   30
# ...

# %%
for i in x_change.columns.values:
    median_=x_change[i].median()
    df[i]=x_change[i].replace(to_replace=0,value=median_)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  DiabetesPedigreeFunction  Age  Outcome
# 0              6      148             72             35     30.5  33.6                     0.627   50        1
# 1              1       85             66             29     30.5  26.6                     0.351   31        0
# 2              8      183             64             23     30.5  23.3                     0.672   32        1
# 3              1       89             66             23     94.0  28.1                     0.167   21        0
# 4              0      137             40             35    168.0  43.1                     2.288   33        1
# ..           ...      ...            ...            ...      ...   ...                       ...  ...      ...
# 763           10      101             76             48    180.0  32.9                     0.171   63        0
# ...

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness  ...         BMI  DiabetesPedigreeFunction         Age     Outcome
# count   768.000000  768.000000     768.000000     768.000000  ...  768.000000                768.000000  768.000000  768.000000
# mean      3.845052  121.656250      72.386719      27.334635  ...   32.450911                  0.471876   33.240885    0.348958
# std       3.369578   30.438286      12.096642       9.229014  ...    6.875366                  0.331329   11.760232    0.476951
# min       0.000000   44.000000      24.000000       7.000000  ...   18.200000                  0.078000   21.000000    0.000000
# 25%       1.000000   99.750000      64.000000      23.000000  ...   27.500000                  0.243750   24.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000  ...   32.000000                  0.372500   29.000000    0.000000
# ...

# %%
x=df.drop(columns=['Outcome'])
x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  DiabetesPedigreeFunction  Age
# 0              6      148             72             35     30.5  33.6                     0.627   50
# 1              1       85             66             29     30.5  26.6                     0.351   31
# 2              8      183             64             23     30.5  23.3                     0.672   32
# 3              1       89             66             23     94.0  28.1                     0.167   21
# 4              0      137             40             35    168.0  43.1                     2.288   33
# ..           ...      ...            ...            ...      ...   ...                       ...  ...
# 763           10      101             76             48    180.0  32.9                     0.171   63
# 764            2      122             70             27     30.5  36.8                     0.340   27
# ...

# %%
y=df['Outcome']
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.model_selection import train_test_split,cross_val_predict

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
scores=[]
depth=range(1,11)
for i in depth:
    model=DecisionTreeClassifier(max_depth=i)
    score=cross_val_predict(model,x,y,cv=5).mean()
    scores.append(score)

# %%
import numpy as np

# %%
best_depth=depth[np.argmax(scores)]
best_depth
# Out:
# 4

# %%
model=DecisionTreeClassifier(max_depth=best_depth)
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accu=accuracy_score(y_test,y_pred)
accu
# Out:
# 0.7402597402597403

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']=False

# %%
plt.figure(figsize=(12,8))
plot_tree(model,filled=True,feature_names=x.columns,class_names=['健康','患病'])
plt.title('糖尿病决策树')
# Out:
# Text(0.5, 1.0, '糖尿病决策树')
